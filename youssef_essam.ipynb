# %% [markdown]
# <a href="https://colab.research.google.com/github/hamedhossam22/repo-Multimodal-Review-Consistency-Detection/blob/main/youssef_essam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Final Model Comparison

comparison_df = pd.DataFrame({

    'Model': [
        'LSTM',
        'BERT',
        'DistilBERT'
    ],

    'Architecture Type': [
        'Traditional Sequence Model',
        'Transformer Model',
        'Lightweight Transformer'
    ],

    'Test Accuracy': [
        0.744,
        0.941,
        0.919
    ],

    'Training Speed': [
        'Medium',
        'Slow',
        'Fast'
    ],

    'Contextual Understanding': [
        'Limited',
        'Excellent',
        'Very Strong'
    ]
})

comparison_df

# %% [markdown]
# # Final Image Models Comparison
#
# import pandas as pd
#
# image_comparison = pd.DataFrame({
#
#     "Model": [
#
#         "Custom CNN",
#         "ResNet50 Transfer Learning"
#
#     ],
#
#     "Architecture Type": [
#
#         "Custom CNN",
#         "Pretrained Transfer Learning"
#
#     ],
#
#     "Test Accuracy": [
#
#         0.714,
#         0.612
#
#     ],
#
#     "Overfitting Risk": [
#
#         "Moderate",
#         "Low"
#
#     ],
#
#     "Suspicious Image Detection": [
#
#         "Strong",
#         "Moderate"
#
#     ]
# })
#
# image_comparison

# %% [markdown]
# # Identify Incorrect BERT Predictions
#
# incorrect_indices = []
#
# for i in range(len(y_test)):
#
#     if y_pred[i] != y_test[i]:
#
#         incorrect_indices.append(i)
#
# print("Number of Incorrect Predictions:", len(incorrect_indices))

# %% [markdown]
# # Display Incorrect Predictions
#
# for i in incorrect_indices[:5]:
#
#     print("Sample Index:", i)
#
#     print("Predicted Label:", y_pred[i])
#
#     print("Actual Label:", y_test[i])
#
#     print("-" * 60)

# %% [markdown]
# Sample Index: 1
# Predicted Label: [0]
# Actual Label: 1
# ------------------------------------------------------------
# Sample Index: 2
# Predicted Label: [0]
# Actual Label: 1
# ------------------------------------------------------------
# Sample Index: 5
# Predicted Label: [0]
# Actual Label: 1
# ------------------------------------------------------------
# Sample Index: 11
# Predicted Label: [0]
# Actual Label: 1
# ------------------------------------------------------------
# Sample Index: 12
# Predicted Label: [0]
# Actual Label: 1
# ------------------------------------------------------------
